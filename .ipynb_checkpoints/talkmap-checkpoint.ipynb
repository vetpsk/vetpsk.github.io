# %% [markdown]
# # Leaflet cluster map of talk locations
#
# Assuming you are working in a Linux or Windows Subsystem for Linux environment, you may need to install some dependencies. Assuming a clean installation, the following will be needed:
#
# ```bash
# sudo apt install jupyter
# sudo apt install python3-pip
# pip install python-frontmatter getorg --upgrade
# ```
#
# After which you can run this from the `_talks/` directory, via:
#
# ```bash
#  jupyter nbconvert --to notebook --execute talkmap.ipynb --output talkmap_out.ipynb
# ```
#
# The `_talks/` directory contains `.md` files of all your talks. This scrapes the location YAML field from each `.md` file, geolocates it with `geopy/Nominatim`, and uses the `getorg` library to output data, HTML, and Javascript for a standalone cluster map.

# %%
# Start by installing the dependencies
# !pip install python-frontmatter getorg --upgrade
import frontmatter
import glob
import getorg
from geopy import Nominatim
from geopy.exc import GeocoderTimedOut
# Out:
# Collecting python-frontmatter
#   Downloading python_frontmatter-1.1.0-py3-none-any.whl.metadata (4.1 kB)
# Collecting getorg
#   Downloading getorg-0.3.1-py2.py3-none-any.whl.metadata (326 bytes)
# Requirement already satisfied: PyYAML in /Users/pranavkulkarni/anaconda3/lib/python3.11/site-packages (from python-frontmatter) (6.0)
# Collecting geopy (from getorg)
#   Downloading geopy-2.4.1-py3-none-any.whl.metadata (6.8 kB)
# Collecting pygithub (from getorg)
#   Downloading PyGithub-2.6.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting retrying (from getorg)
#   Downloading retrying-1.3.4-py3-none-any.whl.metadata (6.9 kB)
# Collecting geographiclib<3,>=1.52 (from geopy->getorg)
#   Downloading geographiclib-2.0-py3-none-any.whl.metadata (1.4 kB)
# Collecting pynacl>=1.4.0 (from pygithub->getorg)
#   Downloading PyNaCl-1.5.0-cp36-abi3-macosx_10_10_universal2.whl.metadata (8.7 kB)
# Requirement already satisfied: requests>=2.14.0 in /Users/pranavkulkarni/anaconda3/lib/python3.11/site-packages (from pygithub->getorg) (2.31.0)
# Requirement already satisfied: pyjwt>=2.4.0 in /Users/pranavkulkarni/anaconda3/lib/python3.11/site-packages (from pyjwt[crypto]>=2.4.0->pygithub->getorg) (2.4.0)
# Requirement already satisfied: typing-extensions>=4.0.0 in /Users/pranavkulkarni/anaconda3/lib/python3.11/site-packages (from pygithub->getorg) (4.7.1)
# Requirement already satisfied: urllib3>=1.26.0 in /Users/pranavkulkarni/anaconda3/lib/python3.11/site-packages (from pygithub->getorg) (1.26.16)
# Collecting Deprecated (from pygithub->getorg)
#   Downloading Deprecated-1.2.18-py2.py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: six>=1.7.0 in /Users/pranavkulkarni/anaconda3/lib/python3.11/site-packages (from retrying->getorg) (1.16.0)
# Requirement already satisfied: cryptography>=3.3.1 in /Users/pranavkulkarni/anaconda3/lib/python3.11/site-packages (from pyjwt[crypto]>=2.4.0->pygithub->getorg) (41.0.3)
# Requirement already satisfied: cffi>=1.4.1 in /Users/pranavkulkarni/anaconda3/lib/python3.11/site-packages (from pynacl>=1.4.0->pygithub->getorg) (1.15.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/pranavkulkarni/anaconda3/lib/python3.11/site-packages (from requests>=2.14.0->pygithub->getorg) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/pranavkulkarni/anaconda3/lib/python3.11/site-packages (from requests>=2.14.0->pygithub->getorg) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/pranavkulkarni/anaconda3/lib/python3.11/site-packages (from requests>=2.14.0->pygithub->getorg) (2023.7.22)
# Requirement already satisfied: wrapt<2,>=1.10 in /Users/pranavkulkarni/anaconda3/lib/python3.11/site-packages (from Deprecated->pygithub->getorg) (1.14.1)
# Requirement already satisfied: pycparser in /Users/pranavkulkarni/anaconda3/lib/python3.11/site-packages (from cffi>=1.4.1->pynacl>=1.4.0->pygithub->getorg) (2.21)
# Downloading python_frontmatter-1.1.0-py3-none-any.whl (9.8 kB)
# Downloading getorg-0.3.1-py2.py3-none-any.whl (39 kB)
# Downloading geopy-2.4.1-py3-none-any.whl (125 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.4/125.4 kB 8.2 MB/s eta 0:00:00
# Downloading PyGithub-2.6.1-py3-none-any.whl (410 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.5/410.5 kB 21.7 MB/s eta 0:00:00
# Downloading retrying-1.3.4-py3-none-any.whl (11 kB)
# Downloading geographiclib-2.0-py3-none-any.whl (40 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.3/40.3 kB 4.5 MB/s eta 0:00:00
# Downloading PyNaCl-1.5.0-cp36-abi3-macosx_10_10_universal2.whl (349 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 349.9/349.9 kB 28.8 MB/s eta 0:00:00
# Downloading Deprecated-1.2.18-py2.py3-none-any.whl (10.0 kB)
# Installing collected packages: retrying, python-frontmatter, geographiclib, Deprecated, pynacl, geopy, pygithub, getorg
# Successfully installed Deprecated-1.2.18 geographiclib-2.0 geopy-2.4.1 getorg-0.3.1 pygithub-2.6.1 pynacl-1.5.0 python-frontmatter-1.1.0 retrying-1.3.4
#
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip
# IPywidgets and ipyleaflet support enabled.

# %%
# Collect the Markdown files
g = glob.glob("_talks/*.md")

# %%
# Set the default timeout, in seconds
TIMEOUT = 5

# Prepare to geolocate
geocoder = Nominatim(user_agent="academicpages.github.io")
location_dict = {}
location = ""
permalink = ""
title = ""

# %% [markdown]
# In the event that this times out with an error, double check to make sure that the location is can be properly geolocated.

# %%
# Perform geolocation
for file in g:
    # Read the file
    data = frontmatter.load(file)
    data = data.to_dict()

    # Press on if the location is not present
    if 'location' not in data:
        continue

    # Prepare the description
    title = data['title'].strip()
    venue = data['venue'].strip()
    location = data['location'].strip()
    description = f"{title}<br />{venue}; {location}"

    # Geocode the location and report the status
    try:
        location_dict[description] = geocoder.geocode(location, timeout=TIMEOUT)
        print(description, location_dict[description])
    except ValueError as ex:
        print(f"Error: geocode failed on input {location} with message {ex}")
    except GeocoderTimedOut as ex:
        print(f"Error: geocode timed out on input {location} with message {ex}")
    except Exception as ex:
        print(f"An unhandled exception occurred while processing input {location} with message {ex}")
# Out:
# VEEC Study Day 2022<br />Wageningen, the Netherlands; Wageningen, The Netherlands Wageningen, Gelderland, Nederland
# UCDavis Postdoctoral Symposium 2024<br />Davis, California, USA; Davis, California, USA Davis, Yolo County, California, United States
# ISVEE 2022<br />Halifax, Canada; Halifax, Canada Halifax, Halifax Regional Municipality, Halifax County, Nova Scotia, Canada
# ISVEE 2024<br />Sydney, Australia; Sydney, Australia Sydney, Council of the City of Sydney, New South Wales, Australia
# EEID 2024<br />Stanford, California, USA; Stanford, California, USA Stanford, Santa Clara County, California, United States
# SVEPM 2021<br />Toulouse, France; Toulouse, France Toulouse, Haute-Garonne, Occitanie, France métropolitaine, France
# ISESSAH 2022<br />Halifax, Canada; Halifax, Canada Halifax, Halifax Regional Municipality, Halifax County, Nova Scotia, Canada
# ISESSAH 2023<br />Helsinki, Finland; Helsinki, Finland Helsinki, Helsingin seutukunta, Uusimaa, Manner-Suomi, Suomi / Finland

# %%
# Save the map
m = getorg.orgmap.create_map_obj()
getorg.orgmap.output_html_cluster_map(location_dict, folder_name="talkmap", hashed_usernames=False)
# Out:
# 'Written map to talkmap/'
